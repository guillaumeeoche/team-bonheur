# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv

# %%
#Changement de répertoire de référence pour le chargement des dataset si besoin
Enquete=pd.read_excel('C:/Users/Shelley Ternon/OneDrive/Bureau/M2/PROJET/team-bonheur-master/Enquête-sur-le-bonheur-3.xlsx')

# %%
Enquete.dtypes
# Out:
# Timestamp                                                                                               datetime64[ns]
# Quel est votre sexe ?                                                                                           object
# Quel est votre âge ? (Ex : 30 pour 30 ans)                                                                       int64
# Dans quel département habitez-vous ? (Ex : 38 pour l'Isère / 0 si hors France)                                   int64
# Etes vous heureux ?                                                                                              int64
# Accordez-vous de l'importance à ... ? (Cochez si oui)                                                           object
# Vous épanouissez-vous dans votre travail ?                                                                     float64
# Accordez-vous de l'importance à l'argent ?                                                                       int64
# Etes-vous plutôt ville ou nature ?                                                                               int64
# Accordez-vous de l'importance à votre temps personnel ?                                                          int64
# Accordez-vous de l'importance aux activités sportives ?                                                          int64
# Accordez-vous de l'importance aux activités créatives ?                                                          int64
# Prenez-vous soin de votre santé ?                                                                                int64
# Accordez-vous de l'importance à votre développement personnel ?                                                  int64
# Quel était votre rêve d'enfant ?                                                                                object
# Si vous fermez les yeux et imaginez un endroit où vous vous sentez bien, comment le décririez-vous ?            object
# Que faites vous qui vous rende heureux pendant votre temps personnel ?                                          object
# Qu'est ce qui vous rend heureux au quotidien ?                                                                  object
# Quel est votre but dans la vie ?                                                                                object
# Qu'est-ce qu'être heureux selon vous ?                                                                          object
# dtype: object

# %% [markdown]
# stat

# %%
plt.hist(Enquete['Etes vous heureux ?'])
plt.show()

# %% [markdown]
# text

# %%
import string # pour charger une librairie de ponctuation (string.punctuation)
import unicodedata # pour remplacer tous les caractères accentués
corpus = Enquete.iloc[:,19]
for i in range(len(corpus)) :
    tmp = str(corpus[i])
    tmp = tmp.lower() # Supprimer les majuscules
    tmp = tmp.replace("'"," ") # Remplacer apostrophe par une espace
    tmp = tmp.replace("\n"," ") # Supprimer les retours chariot
    tmp = tmp.translate(str.maketrans("","", string.punctuation)) # Supprimer la ponctuation
    tmp = tmp.encode('utf-8').decode('utf-8') # Éliminations des caractères spéciaux et accentués
    tmp = unicodedata.normalize('NFD', tmp).encode('ascii', 'ignore')   
    tmp = str(tmp)[2:-1] # Supprimer le préfixe b' qui apparaît lors de la conversion
    corpus[i] = tmp
print(corpus)
# Out:
# 0      etre dans un bon etat d esprit sans angoisse e...
# 1      pour moi c est etre satisfait de soimeme de so...
# 2      etre bien dans sa peau dans sa vie et etre ent...
# 3      accomplir son objectif de vie faire ce qui nou...
# 4                              avoir la paix interieure
#                              ...
# 430    se sentir a sa place au niveau familial profes...
# 431    ma reponse vaut 1 million  desole trop d obser...
# 432    avoir le sourire et faire ce que je veux quand...
# 433                                        etre epanoui
# 434    se sentir bien comble de choses essentielles l...
# Name: Qu'est-ce qu'être heureux selon vous ?, Length: 435, dtype: object
# C:\Users\Shelley Ternon\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
train_tokens = ''
doc =  corpus
doc = doc.apply(lambda x:
                sp(x))
train_tokens = doc

def clean_txt(tokens):
    return [token.lemma_ for token in tokens if (len(token.lemma_)>2 and not token.is_stop and not token.is_punct and not token.is_digit)]

train_clean = train_tokens.apply(clean_txt)
print(train_clean)
# Out:
# 0          [bon, etat, esprit, angoisse, sourire, levre]
# 1      [satisfait, soimeme, entourage, possede, confi...
# 2                             [peau, vie, entoure, aime]
# 3               [accomplir, objectif, vie, faire, coeur]
# 4                                      [paix, interieur]
#                              ...
# 430    [sentir, place, niveau, familial, professionne...
# 431    [reponse, valoir, million, desole, observation...
# 432                   [sourire, faire, vouloir, vouloir]
# 433                                            [epanoui]
# 434    [sentir, comble, chose, essentiel, amour, proc...
# Name: Qu'est-ce qu'être heureux selon vous ?, Length: 435, dtype: object
# ['bon etat esprit angoisse sourire levre',
#  'satisfait soimeme entourage possede confiance capacite fiere vivre vie envie',
#  'peau vie entoure aime',
#  'accomplir objectif vie faire coeur',
#  'paix interieur',
#  'savoir savourer journee savoir difficile',
#  'profiter instant present',
#  'vivre present besoin chose',
#  'vivre vie pouvoir',
#  'trouver point vie leve jour sourire point belle journe',
#  'envie lever matin vie epanouissant riche',
#  'atteindre satisfaction condition',
#  'paix soimeme aimer qualite defaut juste relation vie',
#  'besoin',
#  'voir enfant grandir epanouir reussir realiser choix vie',
#  'strict sante paix soimeme',
#  'question philo',
#  'sentir quotidien epanoui sentir moment vie moment partage famille ami travailactivite professionnelleprojet lieu vie',
#  'accord envie valeur',
#  'accord que que vouloir',
#  'serein avenir lin aim',
#  'tranquille satisfait',
#  'contenter',
#  'prise conscience heureux instant present demain chance pouvoir evidemment',
#  'labri besoin',
#  'satisfaitet bon sante',
#  'rir aimer aim accomplir projet',
#  'dombre tableau souci sante proche joli projet niveau',
#  'accord soimeme principe valeur pouvoir realiser projet tenir cur',
#  'poser question',
#  'vivre moment present detachement',
#  'serein phase',
#  'plutot inconscient long terme mener souhaite entreprendr pouvoir tirer satisfaction',
#  'manquer',
#  'vivre endroit agreabl entoure aime argent',
#  'accepter present travailler future',
#  'chose subjectif normatif heureux sentiment depend multitude facteur classe convenance',
#  'sepanouir',
#  'accord',
#  'insoucier',
#  'heureux malheureux pouvoir satisfair envie decouvrir vie essayer entoure heureux',
#  'equilibre travailfamill entour realiser reve projet',
#  'moment simple phase valeur profiter',
#  'autour famille soutenir',
#  'apaise profiter aime sentir epanouie plan personnel professionnel',
#  'adequation conviction choix',
#  'satisfait vie',
#  'eliminer sentiment negatif inutile agir con venir griller prioritee servir enerver savoir lucide accepter sentiment negatif tirer enseignemer plutot morfondre echouer concour avoir permettre develloper competence prochain fois être meilleur definirer definition bonheur acceptance emotion negativ gommer autant reflechisser nombreux emotion positif synonyme bonheur',
#  'profiter linstant preser lon aime',
#  'epanoui',
#  'sentir satisfaite possede vie mene',
#  'concentre essentielet present',
#  'sourire partager',
#  'savoir aime personne aime pouvoir passer temps personne reussir reve',
#  'parvenir fin cultiver voir proche',
#  'heureux entourer beau personne rendre heureux pousser aller loin vie fin accomplir plan personnel professionnel',
#  'vivre accord valeur',
#  'arriver faire aime savoir que aime',
#  'libre',
#  'apprecier',
#  'savoir apprecier moment partage petit chose insignifiant regarder paysage poser observer nature',
#  'lien famille ami vivre simplement',
#  'aimer aimer aimer soimeme accord vie',
#  'probleme manquer argent',
#  'communiquer sourire aider ecouter',
#  'accord',
#  'vivre moment present pleine conscience amour jugement savoir couper mental vivre moment present fondre',
#  'sennuyer entoure',
#  'depend personne heureux souffrir',
#  'entoure entoure aime',
#  'travail passionnant activiteet famille',
#  'profiter instant present preoccuper avenir ressasser passer',
#  'peau esprit',
#  '',
#  'tete remplir uniquement pensee positif heureux cest envier chose pouvoir realiser facilement seraitce quun verre terrasse prelasser bord leau heureux cest atteindre but difficile dacce cest prendre tete profiter chose simple',
#  'acteur vie subir evenement',
#  'profiter petit instant vie',
#  'subjectif definition temps aim accompagne persiste',
#  'sante epanouissement',
#  'paix',
#  'paix donner sens vie sentiment reconfort lon atteindre transformation developpement personnel',
#  'epanouie domaine social personnellement familial savoir reussir saccorder temps moment',
#  'etat pratique bonheur bonheur aristote pratique intelligence contemplation nature',
#  'esprit calme corps sain',
#  'bon question',
#  'sepanouir travail famille soude ami present',
#  'cest ancre accord ecouter cur paix',
#  'construit propre bonheur definition bonheur savoir jouir apaisee',
#  'vivre harmonie famille faire vouloir retrouver frequemment partager bon moment',
#  'capacite redonner bonheur',
#  'vivre pleinement profitez instant',
#  'trouver mission vie accomplir',
#  'paix faire quon aime jour gros impact positif terre faire avancer lhumanite contribuer bonheur epanouissement',
#  'entouree bienveillant monde paix',
#  'pouvoir faire vouloir vouloir',
#  'attitude positif linstant',
#  'trouve reponse',
#  'temps',
#  'heureux favoriser secretion hormone provoquer bienetre limiter souffrance',
#  'tete',
#  'temps',
#  'sentir vie aimer projet aimer quotidien',
#  'serenite confiance avenir savoir terrible',
#  'crainte aujourdhui lavenir allez travail boule ventre entoure personne voir temps passer',
#  'sentir basquette vivre regret',
#  'lever sourire apprecier lon courrir chose',
#  'realiser creer qqch',
#  'accord soimeme',
#  'heureux cest profiter chq inster arreter qques seconde journee compte heureux vouloir sentimentnotre situation dure',
#  'savoir savourer entour',
#  'bonheur illusoire',
#  'sensation bienetre malheureusement temporaire',
#  'regarder monde travers oeil enfant prise tete eloigner toxique relativiser apprecier impression herbe vert voisin',
#  'cest profonde conviction propre valeur moral proche',
#  'voir enfant petitsenfant heureux',
#  'aimer proche aime proche',
#  'sensation contraindre faire chose',
#  'melange joie amour bonheur',
#  'prendre plaisir petit chose quotidien famille ami proche aimer pouvoir aimer',
#  'epanouie',
#  'satisfair besoin',
#  'heureux place vivre climat bienveillance confiance trouve sens plaisir agir apte relever challenge presenter assurer bon equilibre vie pro perso',
#  'sentir place sentir personne entourer besoin jouer role plaire satisfaire que aimer recevoir amour',
#  'faire quon envier',
#  'combinaison chose quotidien amities amour',
#  'nayer contraint materiel faire choix',
#  'projet temps penser heureux',
#  'epanoie donne force curiosite savoir recevoir amour donner attendre rayonner attirer nouveau rencontre opportunite',
#  'pouvoir faire choix librement moyen faire choix',
#  'maitr vie',
#  'trouver sweet spot ikigai',
#  'harmonie echange proche',
#  'intrinsequement idee sentir libre idee accomplissement idee bonheur rejoindre liberte sens liberte absence entrav plutot force individu developp luimeme contrainte',
#  'avancer sereinement avenir acceptation advenir apprecier situation present',
#  'autant satisfait professionnellement personnellement pouvoir epanouie',
#  'epanouie aspect',
#  'voir cote positif evenement arriver sentir proche amour entourage sentir detendu jamais stress chose',
#  'lever matin sourire bonheur interieur',
#  'poser question',
#  'explique voir',
#  'faire que aime quotidien savoir voir verre moitir plutot que moitir vide apprecier chance que',
#  'savoir contenter',
#  'vie problemeprobleme financier familial',
#  'faire aime point vue personnel professionnel stress',
#  'entoure personne aime liberer contrainte materielle',
#  'sentir soi tete',
#  'contraire parisien',
#  'parvenir fin cultiver voir proche',
#  'raison lacher vie',
#  'nsp',
#  'manquer nourriture chauffage aimer travaille cadre vie',
#  'accord choix subir vie',
#  'sepanouir sereinemer vie',
#  'savoir accepter',
#  'pouvoir libre faire souhaite pouvoir balader soucier regard faire rue pouvoir debarrasser ami toxique soucier',
#  'saimer apprecier quon cherir entoure',
#  'satisfaction personnel champ vie famill profession sant argent',
#  'profiter vie prendre tete quitter job ininteressant faire motive vraiment prendre soin developpement personnel nourritur sant',
#  'serein phase',
#  'vivre personne que aime faire que aime',
#  'aimer aimer',
#  'communiquer sourire aider ecouter',
#  'justifier acte',
#  'burger king',
#  'mean happy feeling good from insid like you plan something past and make true future and make you happy after',
#  'reussir voir verre moitir trouver equilibre',
#  'pouvoir vivre affranchissant regard',
#  'vivre proche poser question sante argent passer temps faire activite que apprecie faire',
#  'pouvoir faire que vouloir vouloir',
#  'serin obnubile dautre sentiment lieu',
#  'epanouir petit chose',
#  'epanouie entour',
#  'famille travail stress',
#  'definition aime apprendre chose jour',
#  'sentir complet accord',
#  'entouree',
#  'libre faire quon vouloir vouloir vouloir vouloir',
#  'sentiment apaisemer attendre',
#  'continuer avancer moment doute difficulte regarder faire regarder projet',
#  'content lever matin',
#  'famille capacite aider niveau financier bon sante',
#  'sante paix vivre pays democratique bon situation financiere aide',
#  'bon question content petit chose quotidien satisfaire petit petit victoire apprecier',
#  'sentir leger sourire naturellement forcer',
#  'coherent',
#  'vivre accord chose entourer sentir contrainte sentir libre vivre experience voyager trouver sens choix vie',
#  'prendre tete vivre envier',
#  'bonheur chemin empreindre finalite heureux conscient parcourir chemin',
#  '',
#  'sentir vivre present',
#  '',
#  'cest davoir vie social professionnel equilibree entoure beau personne famille soude',
#  'sentir peau',
#  'manger',
#  'quotidien savoir faire plaisir decouvrir nouveau chose passer moment agreable groupe ami',
#  'epanouie profiter vie enviespassionsbesoin trouver equilibre plaisir contraindre vie',
#  'heureux pose question cest ressentir moment bonheur jamais devoir heureux intermittence etat conster bonheur impossible souffrir apprendre heureux',
#  'personne que aime pression',
#  'accepter haut sentir corps tete epanouir professionnel relation amical amoureux',
#  'accomplir plan vivre paix',
#  'savoir contenter profiter instant epanouir activite professionnel personnelle',
#  'heureux accepte',
#  'aimer vivre bon sante',
#  'realiser heureux sentir realisation profiter compliqu decrire sentiment sourire',
#  'wow bon question sentir sentir satisfaite apaise reconnaissant savoir acceptation situation vie accepter imparfait vivre',
#  'profiter moment present',
#  'profiter instant',
#  'aimer aime',
#  'penser vie autant arreter reflechir accepte epreuve difficile douloureuse surmonter vouloir ressentir dire que heureux apprecier douleur vie somme',
#  'paix',
#  'etat satisfaction general niveau pro perso',
#  'sentir vivant',
#  'aim aim sensation grandir interieuremer fier choix acte',
#  'vivre heureux autrew',
#  'apprecier moment present reconnaitre',
#  'reveiller matin vivre vie poser question probleme sante perso famille probleme argent toit manger angoisse lendemain',
#  'devoir expliquer que couleur rouge dire forme alternatif plaisir parcimonieux constant',
#  'famille',
#  'sentir situation bonheur limite frontiere bonheur ideal atteindre fois atteindre reellemer heureux objectif eloigner bonheur finalement deduire heureux etat homme vise ideal pouvoir beneficier court instant instant prendra fin prendre conscience',
#  'savoir profiter petit instant jour',
#  'sentir opprim contrainte exterieure',
#  'savoir apprecier',
#  'savoir equilibrer vie personnel professionnel',
#  'sentir peau',
#  '',
#  'fier satisfaire',
#  'vivre entendre',
#  'libre sourire',
#  'accepter',
#  'question hormone vraiment heureux falloir reflechir bonheur malheureux vivre pleine sant conscier reconnaître heureux',
#  'entoure toit partager bonheur',
#  'aimer aimer',
#  'reveiller matin sourire matin compte petit bonheur vie',
#  'sereine',
#  'stress',
#  'plaisir lever matin commencer nouvelle journe',
#  'vivre moment present profiter pleinement sante',
#  'sentir leger sourire naturellement forcer',
#  'definit',
#  'apprecier',
#  'sentir efforcer quotidien realiser objectif cueillir fruit',
#  'sentir epanoui soimeme',
#  'vivre vie lentend',
#  'travailler',
#  'nsp',
#  'lever plaisir',
#  'savoir',
#  'souci reve accomplir',
#  'profiter moment',
#  'nsp',
#  'profiter instant present',
#  'sentir contrainte environnement libre faire envier',
#  'peau tete',
#  'savoir apprecier possede',
#  'sentir vie vivre fondre regret',
#  'aimer aimee profiter que',
#  'ressentir joieaimer aime',
#  'choix choix libre',
#  '',
#  'harmonie voir',
#  'profiter petit moment bonheur jaim',
#  'poser genre question',
#  'satisfaire moment simple heureux',
#  'parvenir realiser projet faire aime aime',
#  'etat',
#  'trouver lequilibr',
#  'savoir apprecier temps aim',
#  'feliciter que',
#  'sentiment plenitude peau vie',
#  'lepanouissemer fois travail personnelle',
#  'sentir epanouie vie personnel professionnel',
#  'lon entrave',
#  'regarder desir',
#  'vivre accord soucier temps profiter instant present',
#  'vivre vie regret',
#  'nest labsence problème maniere detre heureux cest detre famille daccomplir projet feter anniversaire faire apero boire coup problème permettre savourer dauter instant bonheur gras cest vie      faire reblochonade soir sante ami bon courage etude',
#  'profiter lon changer convier rire partager aimer crier sauter chanter trinquer',
#  'vouloir lon possede',
#  'libre choix',
#  '',
#  'moment plenitude fugace etat permanent',
#  'sentir corps tete',
#  'profiter lon changer convier rire partager aimer crier sauter chanter trinquer',
#  '',
#  'vivant profiter moment triste joyeux',
#  'notion equilibre plan personnel amoureux professionnel',
#  'profiter petit bonheur jour voir cote positif situation vie agreabl aide heureux',
#  'vivre',
#  'faire sorte realiser reve trouver equilibre vie social epanouissement personnel',
#  'savoir etat esprit prefere voir verre moitir moitir vide',
#  'vivre instant pleinement quil arrive rester positive',
#  'atteindre objectif sentir faire sorte sentir personnellemer bel relation couple aide avancer appaisser cherche jour chose stressee profiter instant present aim important prendre tps sport sentir libre',
#  'sentir harmonie sentir legere rayonnant',
#  'construire vie valeur principe objectif long terme porter donner energie vital',
#  'accord aligne paix',
#  'sentir bon sante',
#  'important manquer partager',
#  'apprecier vie',
#  'sante epanouissement professionnel complicite femme minimum satisfaire besoin famille sentir aimer',
#  'reussir profiter vie simplement prendre tete',
#  'regarder arriere profiter instant voir verre moitir que moitir vide partager',
#  'depense compter',
#  'heureux souci cote prendre temps aider',
#  'moment vie triste recevoir lettre poudlard',
#  'maitriser vie',
#  'choix vie ecouter atant service',
#  'minimum stress',
#  'apprecier instant desirer lon',
#  'heureux cest harmonie cest trouve voie cur trouver voie general cest donner bonheur bienveillant apaisee cest alle chemin quon choisir impose',
#  'vivre satisfaction personnelle permettre depasser souci vie bonheur participer bonheur',
#  'accord corps esprit',
#  'phase lamour inconditionnel trouver reponse chemin',
#  'souci corps',
#  'profiter vie',
#  'sentiment realiser donner bonheur entourage',
#  'sentir bon endroit place accord valeur croyance approcher reve',
#  'aimer aimer',
#  'serein',
#  'apaise stresse subir charge mental pouvoir profiter famille ami passer bon moment pression contrainte',
#  'realiser reve fiche dire',
#  'sentir leger',
#  'famille maison travail ami argent manger',
#  'ensemble petit bien mettre bout bout capacite surmonter epreuve inevitablesi',
#  'epanouie sentir',
#  'entouree ami enfant',
#  'peau',
#  'savoir contenter',
#  'sante bonheur',
#  'contenter quon vivre accord',
#  'peau epanouissement personnel professionnel',
#  'solution probleme',
#  'sentir preoccuper souci materiel',
#  'accord soimeme desir projet aimer aime',
#  'etat bonheur existe resulte concert petit moment heureux passer bon moment vouloir vouloir vouloir',
#  'arreter vouloir aimer que',
#  'accord',
#  'sentir amuser',
#  'fiere',
#  'libre faire sport veut',
#  'besoin poser question',
#  'vie envier',
#  'satisfaire',
#  'arriver accepter force faiblesse savoir quelquefois',
#  'sante heureux vie privee',
#  'petit bonheur',
#  'malheureux triste angoisse anxieux',
#  'sourire faire chose plaisir content faire lon apprecier detre lon',
#  'jarriv atteindre but',
#  'profiter lon',
#  'faire envie envie',
#  'vie connaitre',
#  'profiter',
#  'conscient',
#  'profiter instant',
#  'bon sante que aime epanouir activite professionnel pler gagner suffisamment argent faire plaisir profiter passer aime',
#  'peau pouvoir faire quon vouloir regret suite',
#  'sentir',
#  'sentiment general moment ponctuel trister douloureux sentiment accomplissement foi avenir avenir securis probleme important perspective sante familial projet que être personnels etou professionnel espoir concretisation',
#  'epanouir pler être souriant heureux autour',
#  'compte chance boulot sante famille ami maison chercher positif tte situation',
#  'carp diem',
#  'sentir accord soimeme nature',
#  'falloir bon sante crainte futur',
#  'adequation',
#  'sentiment plenitude joie',
#  '',
#  'passer temps personne grandir temps cercle temps faire grandir',
#  'eviter regret regarder passe nostalgique',
#  'savoir aime merite amour',
#  'courir',
#  'bonheur etat desprit',
#  'content vivre',
#  'sentir interieurement cur tete totalement remplir chose sentir phase nousmeme',
#  'tete vie',
#  'heureux accompagne vie sentir entourage positif partager chose',
#  'bonheur etat desprit',
#  'sante',
#  'bonheur etat desprit',
#  'anxieux soucieux sentir',
#  'epanouis vie aim que jour profite moment',
#  'heureux parvenir accomplissement objectif professionnel personnel fiere',
#  'epanoui sentir circonstance',
#  'epanoui',
#  'heureux lever matin',
#  'etat esprit general sentiment satisfaction permanent moment triste pouvoir heureux chercher vouloir derniere nouveaute falloir savoir satisfaire optimiste voir bon cote chose',
#  'famille sante',
#  'profiter vie',
#  'vivre vie pleinement profiter souci',
#  'question difficile',
#  'limite fixer environnement sentir libre',
#  'jamais triste colere',
#  'tete faire que aime',
#  'paix soi aimer chose simple vie cest commencer debut bonheur personnel',
#  'sentir',
#  'bonheur etat desprit',
#  'sentir adequation soimeme',
#  'serein remplir stimule lamour',
#  'emmerde reposer bon sante',
#  'cest autour heureux',
#  'content lever matin',
#  'vivre jour jour',
#  'satisfait vie',
#  'heureux entoure que aime',
#  'envie intuition partager essayer lacherprise probleme voir bonheur venir',
#  'epanoui couple vie generale',
#  'developper decouvrir exercer activite etou metier passionne passer temps qualite proche construire projet',
#  'libre regard savoir origine emotion',
#  'bon question cest notion complexe bonheur bon courage etude',
#  'savoir enfant',
#  'confiante',
#  'tete vivre que desir',
#  'epanouie aller decouverte monde',
#  'aimeeet independant financierement',
#  'corps relache tension pensee negative',
#  'aimer aime entraider',
#  'faire pler',
#  'aise environnement epanouisser intellectuellement relationnellement',
#  'bonheur accord souhaite',
#  'profiter petit moment partage proche moment profiter paysage symper aime petit accomplissement avancees personnel professionnel',
#  'chose sante fer subtil equilibre travail passionne ambiance sain travail vie sentimental coups environnement vie agreabl',
#  'pouvoir manger grossir',
#  'sentir vivre vie lentend',
#  'sourire lheure reveil',
#  'sentir vie',
#  'accepter surmonter souffrance vie probleme inherent vie detach',
#  'accepter surmonter souffrance vie probleme inherent vie detach',
#  'sentir equilibre environnement soimem proche',
#  'accepter soismeme partager bonheur',
#  'profiter moment cours inquieter',
#  'tranquille content quon voir entourage',
#  'sentir place niveau familial professionnel personnel',
#  'reponse valoir million desole observation analyser gratuitement',
#  'sourire faire vouloir vouloir',
#  'epanoui',
#  'sentir comble chose essentiel amour proche reconnaissance travail bon sante chercher heureux 24h24 plutot profiter petit moment bonheur quotidien belle soiree ami famille bon repas vacance decide heureux decide vouloir vie devenir reellement heureux']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()


if __name__ == '__main__':

    show_wordcloud(train_clean)
